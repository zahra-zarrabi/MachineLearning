# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv

# %%
def generate_data(n):
    height=np.random.randint(50,220,n)
    slope=np.random.uniform(0.2,0.4,n)
    b=np.random.uniform(4,1,n)
    weight=height*slope +b
    return height,weight

# %%
height,weight=generate_data(n=100)
print(height,weight)
# Out:
# [109  75 112 210  62 193  98 134 209 164 102  53  93 146 151 122  89 156
#  180 131 125 186 176 188 164 165  88  91 208  58  79 116 160  78 156  96
#   90  90 218  84  67 115 112 139 125 169 175 116 173 147 134  68 104  89
#  181  90 216 176  53 195 140  55 211 180 202 187 213 105  89 189 172 176
#   75 158  94 164 141  93 120  71 143 124  65  59  80 142  91  76 182 111
#  174 150  53  68  75  87 213  90  68 126] [36.3977915  31.54686663 40.51379964 45.37390566 15.47114049 59.43099519
#  41.56068986 51.13252228 64.67333642 47.49706703 38.99071841 16.28730129
#  31.6721524  38.66862487 41.61483221 39.97304113 25.24729156 59.80797077
#  42.0554569  36.96016043 31.30334308 46.8253739  45.50485639 54.18757285
#  47.51342866 37.02129223 25.34485204 34.71408016 82.02859921 16.24574291
#  19.60901712 29.63715189 60.20475079 26.42834559 62.76904348 23.7724737
#  27.05557581 32.3053621  61.19868254 31.67924341 18.74377753 28.21144289
# ...

# %%
X=height.reshape(-1,1)
Y=weight.reshape(-1,1)
print(X.shape)
print(Y.shape)
# Out:
# (100, 1)
# (100, 1)

# %%
# plt random slope

for m in range(1,4):
    Y_pred=np.matmul(X,[m])
    plt.plot(X,Y_pred,c='red')
    

plt.scatter(X,Y)
plt.xlabel('Height')
plt.ylabel('Weight')
# Out:
# Text(0, 0.5, 'Weight')

# %%
#plt slope Adaline
m=np.matmul(inv(np.matmul(X.T,X)),np.matmul(X.T,Y))
y_pred=np.matmul(X,m)
plt.scatter(X,Y)
plt.plot(X,y_pred,c='red')

# %%
#linregress
from scipy.stats import linregress
result=linregress(X[:,0],Y[:,0])
print(result.slope)
y_pred=result.intercept + np.matmul(X,np.array([[result.slope]]))
plt.scatter(X,Y)
plt.plot(X,y_pred,c='red')
plt.xlabel('Height')
plt.ylabel('Weight')
# Out:
# 0.30758292198692483
# Text(0, 0.5, 'Weight')
